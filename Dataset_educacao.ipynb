# %% [markdown]
# <a href="https://colab.research.google.com/github/vitoria-raupp/TrabalhoVisualizacaoDeDadosEducacionais/blob/main/Dataset_educacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
dados = pd.read_csv('/content/dado.csv') #tabela "microdados_ed_basica_2021(henrique)"

# %%
dados
# Out:
#            NO_REGIAO             NO_UF SG_UF           NO_MUNICIPIO  \
# 0              Norte          Rondônia    RO  Alta Floresta D'Oeste
# 1              Norte          Rondônia    RO  Alta Floresta D'Oeste
# 2              Norte          Rondônia    RO  Alta Floresta D'Oeste
# 3              Norte          Rondônia    RO  Alta Floresta D'Oeste
# 4              Norte          Rondônia    RO  Alta Floresta D'Oeste
# ...              ...               ...   ...                    ...
# 221135  Centro-Oeste  Distrito Federal    DF               Brasília
# 221136  Centro-Oeste  Distrito Federal    DF               Brasília
# 221137  Centro-Oeste  Distrito Federal    DF               Brasília
# 221138  Centro-Oeste  Distrito Federal    DF               Brasília
# 221139  Centro-Oeste  Distrito Federal    DF               Brasília
#
#                                 NO_ENTIDADE  TP_DEPENDENCIA  \
# 0                     EIEEF HAP BITT TUPARI               2
# ...

# %%
dados.dtypes
# Out:
# NO_REGIAO                        object
# NO_UF                            object
# SG_UF                            object
# NO_MUNICIPIO                     object
# NO_ENTIDADE                      object
# TP_DEPENDENCIA                    int64
# TP_CATEGORIA_ESCOLA_PRIVADA       int64
# TP_LOCALIZACAO                    int64
# TP_LOCALIZACAO_DIFERENCIADA       int64
# IN_LABORATORIO_INFORMATICA        int64
# IN_EQUIP_LOUSA_DIGITAL            int64
# QT_EQUIP_LOUSA_DIGITAL            int64
# IN_EQUIP_MULTIMIDIA               int64
# QT_EQUIP_MULTIMIDIA               int64
# IN_DESKTOP_ALUNO                  int64
# QT_DESKTOP_ALUNO                  int64
# IN_COMP_PORTATIL_ALUNO            int64
# QT_COMP_PORTATIL_ALUNO            int64
# IN_TABLET_ALUNO                   int64
# QT_TABLET_ALUNO                   int64
# IN_INTERNET                       int64
# IN_INTERNET_ALUNOS                int64
# IN_INTERNET_APRENDIZAGEM          int64
# ...

# %%
dados.values
# Out:
# array([['Norte', 'Rondônia', 'RO', ..., 0, 9, 0],
#        ['Norte', 'Rondônia', 'RO', ..., 1, 1, 1],
#        ['Norte', 'Rondônia', 'RO', ..., 0, 9, 0],
#        ...,
#        ['Centro-Oeste', 'Distrito Federal', 'DF', ..., 1, 1, 1],
#        ['Centro-Oeste', 'Distrito Federal', 'DF', ..., 0, 0, 0],
#        ['Centro-Oeste', 'Distrito Federal', 'DF', ..., 0, 0, 0]],
#       dtype=object)

# %%
dados.tail()
# Out:
#            NO_REGIAO             NO_UF SG_UF NO_MUNICIPIO  \
# 221135  Centro-Oeste  Distrito Federal    DF     Brasília
# 221136  Centro-Oeste  Distrito Federal    DF     Brasília
# 221137  Centro-Oeste  Distrito Federal    DF     Brasília
# 221138  Centro-Oeste  Distrito Federal    DF     Brasília
# 221139  Centro-Oeste  Distrito Federal    DF     Brasília
#
#                                 NO_ENTIDADE  TP_DEPENDENCIA  \
# 221135                    ESC DIVINO MESTRE               4
# 221136                COBIAN - COL BIANGULO               4
# 221137                    CED VITORIA REGIA               4
# 221138            CED SANTOS DUMONT - CESAN               4
# 221139  OBRA SOCIAL NOSSA SENHORA DE FATIMA               4
#
#         TP_CATEGORIA_ESCOLA_PRIVADA  TP_LOCALIZACAO  \
# 221135                            0               1
# 221136                            1               1
# 221137                            1               1
# ...

# %%
labInformatica = dados['IN_LABORATORIO_INFORMATICA']

# %%
labInformatica
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 221135    0
# 221136    1
# 221137    1
# 221138    0
# 221139    0
# Name: IN_LABORATORIO_INFORMATICA, Length: 221140, dtype: int64

# %%
estado = dados['SG_UF']

# %%
comp_por_aluno = dados['QT_COMP_PORTATIL_ALUNO']

# %%
comp_por_aluno.count()
# Out:
# 221140

# %%
estado.value_counts().sort_index
# Out:
# <bound method Series.sort_index of SP    33989
# MG    24023
# BA    20156
# MA    14162
# RJ    13282
# PA    12395
# RS    11631
# CE    10654
# PE    10509
# PR    10079
# SC     7308
# PI     6645
# AM     6251
# PB     5638
# RN     5293
# GO     5152
# ES     4035
# AL     3435
# MT     3211
# SE     2547
# TO     2409
# MS     1889
# AC     1734
# RO     1431
# DF     1407
# RR      941
# AP      934
# Name: SG_UF, dtype: int64>

# %%
estado.hist(bins=27, figsize = (15, 10))
# Out:
# <Axes: >
